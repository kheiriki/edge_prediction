# %%
import pandas as pd
import numpy as np
import networkx as nx
g1=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round1.pkl")
g2=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round2.pkl")
g3=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round3.pkl")
g4=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round4.pkl")
g5=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round5.pkl")
g6=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round6.pkl")
g7=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round7.pkl")
g8=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round8.pkl")
g9=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round9.pkl")
g10=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round10.pkl")
g11=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round11.pkl")
g12=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round12.pkl")
g13=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round13.pkl")
g14=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round14.pkl")
g15=pd.read_pickle("/media/EXTHDD/UnfollowData/WeeklySnapshots/round1-15/community/graph_round15.pkl")
def find_union_of_nodes_in_multiple_graphs(graphs):
    nodes = set()
    for graph in graphs:
        nodes |= set(graph.nodes)
    return nodes

whole_nodes = find_union_of_nodes_in_multiple_graphs(g)

# %%
g = [g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12,g13,g14,g15]

def find_union_of_edges_in_multiple_graphs(graphs):
  edges = set()
  for graph in graphs:
    edges |= set([tuple(sorted((u,v))) for u,v in graph.edges])
  return edges

whole_edges = find_union_of_edges_in_multiple_graphs(g)

# %%
def check_edges_with_networkx(G, node1, node2):
    result = dict()
    if G.has_edge(node1, node2):
        if G.has_edge(node2, node1):
            result[node1,node2,1] = "d2"
        else:
            result[node1,node2,1] = "d4"
    elif G.has_edge(node2,node1):
        if G.has_edge(node1,node2):
            result[node2,node1,1] = "d4"
        else:
            result[node2,node1,1] = "d2"
        
    else:
        result[node1, node2,1]= "d1"
    return result
result1 = dict()
for (u,f) in whole_edges:
    result = check_edges_with_networkx(g1,u,f)
    result1.update(result)
def create_df(result):
    node1 = [key[0] for key in result.keys()]
    node2 = [key[1] for key in result.keys()]
    type = [value for value in result.values()]
    df = pd.DataFrame({"node1": node1, "node2": node2, "type": type})
    return df
df1=create_df(result1)
df1.type.value_counts()

# %%
result2=dict()
import networkx as nx
def check_edges_with_networkx(G,result,result2,i, node1, node2):
    if G.has_edge(node1, node2):
        if G.has_edge(node2, node1):
            #n1<->n2
            if result.get((node1,node2,i-1)) == "d2":
                    result2[node1, node2,i]= "d4"
            elif result.get((node1,node2,i-1)) == "d4": 
                result2[node1, node2,i]= "d4" 
            elif result.get((node1,node2,i-1)) == "d6": 
                result2[node1, node2,i]= "d6" 
            elif result.get((node1,node2,i-1)) == "d5": 
                result2[node1, node2,i]= "d6"
            elif result.get((node2,node1,i-1)) == "d5": 
                result2[node2,node1,i]= "d6"
            elif result.get((node1,node2,i-1)) == "d1": 
                result2[node1, node2,i]= "d4"
            elif result.get((node1,node2,i-1)) == "d3": 
                result2[node1, node2,i]= "d4"
            elif result.get((node2,node1,i-1)) == "d2":
                result2[node2,node1,i]= "d4"
            elif result.get((node2,node1,i-1)) == "d4": 
                result2[node2,node1,i]= "d4" 
            elif result.get((node2,node1,i-1)) == "d6": 
                result2[node2,node1,i]= "d6" 
            elif result.get((node2,node1,i-1)) == "d5": 
                result2[node2,node1,i]= "d6"
            elif result.get((node2,node1,i-1)) == "d5": 
                result2[node2,node1,i]= "d6"
            elif result.get((node2,node1,i-1)) == "d1": 
                result2[node2,node1,i]= "d4"
            elif result.get((node2,node1,i-1)) == "d3": 
                result2[node2,node1,i]= "d4"
        else:
            #n1->n2
            if result.get((node1,node2,i-1)) == "d1":
                result2[node1, node2,i]= "d2"
            elif result.get((node1,node2,i-1)) == "d2":
                result2[node1, node2,i]= "d2"
            elif result.get((node1,node2,i-1)) == "d3":
                result2[node1, node2,i]= "d2"
            elif result.get((node2,node1,i-1)) == "d3":
                result2[node2,node1,i]= "d2"
            elif result.get((node1,node2,i-1)) == "d4": 
                result2[node1, node2,i]= "d5"      
            elif result.get((node1,node2,i-1)) == "d5": 
                result2[node1, node2,i]= "d5"  
            elif result.get((node1,node2,i-1)) == "d6": 
                result2[node1, node2,i]= "d5"
            elif result.get((node2,node1,i-1)) == "d1":
                result2[node2, node1,i]= "d2"
            elif result.get((node2,node1,i-1)) == "d2":
                result2[node2, node1,i]= "d2"
            elif result.get((node2,node1,i-1)) == "d4": 
                result2[node2,node1,i]= "d5"      
            elif result.get((node2,node1,i-1)) == "d5": 
                result2[node2,node1,i]= "d5"  
            elif result.get((node2,node1,i-1)) == "d6": 
                result2[node2,node1,i]= "d5"
             
                
            
    elif G.has_edge(node2, node1):
        if G.has_edge(node1, node2):
            #n1<->n2
            if result.get((node2,node1,i-1)) == "d2":
                result2[node2,node1,i]= "d4"
            elif result.get((node2,node1,i-1)) == "d4": 
                result2[node2,node1,i]= "d4" 
            elif result.get((node2,node1,i-1)) == "d6": 
                result2[node2,node1,i]= "d6" 
            elif result.get((node2,node1,i-1)) == "d5": 
                result2[node2,node1,i]= "d6"
            elif result.get((node2,node1,i-1)) == "d5": 
                result2[node2,node1,i]= "d6"
            elif result.get((node2,node1,i-1)) == "d1": 
                result2[node2,node1,i]= "d4"
            elif result.get((node2,node1,i-1)) == "d3": 
                result2[node2,node1,i]= "d4"
        else:
            if result.get((node1,node2,i-1)) == "d1":
                result2[node1, node2,i]= "d2"
            if result.get((node1,node2,i-1)) == "d1":
                result2[node1, node2,i]= "d2"
            elif result.get((node2,node1,i-1)) == "d2":
                result2[node2,node1,i]= "d2"
            elif result.get((node1,node2,i-1)) == "d2":
                result2[node1,node2,i]= "d2"
            elif result.get((node2,node1,i-1)) == "d3":
                result2[node2,node1,i]= "d2"
            elif result.get((node1,node2,i-1)) == "d3":
                result2[node1, node2,i]= "d2"
            elif result.get((node2,node1,i-1)) == "d4": 
                result2[node2,node1,i]= "d5"    
            elif result.get((node1,node2,i-1)) == "d4": 
                result2[node1,node2,i]= "d5"   
            elif result.get((node2,node1,i-1)) == "d5": 
                result2[node2,node1,i]= "d5"  
            elif result.get((node2,node1,i-1)) == "d6": 
                result2[node2,node1,i]= "d5"
            elif result.get((node1,node2,i-1)) == "d6": 
                result2[node1,node2,i]= "d5"
            elif result.get((node1,node2,i-1)) == "d5": 
                result2[node1,node2,i]= "d5" 
            else:
                result2[node1,node2,i]="NA55"
                print(node1,node2,i-1)
    
    else:
        if result.get((node1,node2,i-1)) == "d3":
            if G.has_edge(node2, node1):
                result2[node1, node2,i]= "d5"
            else:
                result2[node1, node2,i]= "d3"
        elif result.get((node2,node1,i-1)) == "d3":
            if G.has_edge(node1, node2):
                result2[node1, node2,i]= "d5"
            else:
                result2[node1, node2,i]= "d3"
        
        elif result.get((node1,node2,i-1)) == "d1":
            result2[node1, node2,i]= "d1"
        elif result.get((node1,node2,i-1)) == "d2":
            result2[node1, node2,i]= "d3"
        elif result.get((node2,node1,i-1)) == "d2":
            result2[node2,node1,i]= "d3"
        elif result.get((node1,node2,i-1)) == "d4":
            result2[node1, node2,i]= "d6"
        elif result.get((node1,node2,i-1)) == "d5":
            result2[node1, node2,i]= "d6"
        elif result.get((node1,node2,i-1)) == "d6":
            result2[node1, node2,i]= "d6"
        elif result.get((node2,node1,i-1)) == "d1":
            result2[node2,node1,i]= "d1"
        elif result.get((node2,node1,i-1)) == "d2":
            result2[node2,node1,i]= "d3"
        elif result.get((node2,node1,i-1)) == "d2":
            result2[node2,node1,i]= "d3"
        elif result.get((node2,node1,i-1)) == "d4":
            result2[node2,node1,i]= "d6"
        elif result.get((node2,node1,i-1)) == "d5":
            result2[node2,node1,i]= "d6"
        elif result.get((node2,node1,i-1)) == "d6":
            result2[node2,node1,i]= "d6"
        else:
            result2[node1, node2,i]= "NA3"   
    return result2

# %%
for i in range(2,16):
    globals()[f'result{i}']=dict()
    for (u,f) in whole_edges:
        (check_edges_with_networkx(globals()[f'g{i}'],globals()[f'result{i-1}'],globals()[f'result{i}'],i,u,f))
    globals()[f'df{i}']= create_df(globals()[f'result{i}'])

# %%
dff=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15]

# %%
for i, df in enumerate(dff):
    df['label'] = 'Bidirectional'
    df.loc[df['type'] == 'd1', 'label'] = 'Pre-formation'
    df.loc[df['type'].isin(['d2', 'd3']), 'label'] = 'Unidirectional'
    pre_formation_df = df[df.label=='Pre-formation']
    unidirectional_df = df[df.label=='Unidirectional']
    bidirectional_df = df[df.label=='Bidirectional']
    pre_formation_df1=pd.DataFrame()
    pre_formation_df1[['src_id','dst_id','label']]=pre_formation_df[['node1','node2','label']]
    pre_formation_df1['label']=1
    unidirectional_df1=pd.DataFrame()
    unidirectional_df1[['src_id','dst_id','label']]=unidirectional_df[['node1','node2','label']]
    unidirectional_df1['label']=2
    bidirectional_df1=pd.DataFrame()
    bidirectional_df1[['src_id','dst_id','label']]=bidirectional_df[['node1','node2','label']]
    
    bidirectional_df1['label']=3

    pre_formation_df1.to_csv(f"pre_formation_df{i+1}.csv")
    unidirectional_df1.to_csv(f"unidirectional_df{i+1}.csv")
    bidirectional_df1.to_csv(f"bidirectional_df{i+1}.csv")

# %%
for i in dff:
    print(i)
